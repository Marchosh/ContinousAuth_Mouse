# %%
import pandas as pd

data = pd.read_csv("TF2_selected.csv")
data.head()
# Out:
#    Unnamed: 0    Y  Stop_Duration    X        Jerk  Direction_Change  \
# 0           0  500           -0.0  579 -319.936258                 1
# 1           1  499           -0.0  580  163.618411                 1
# 2           2  499           -0.0  581    0.407641                 1
# 3           3  499           -0.0  583    1.414214                 0
# 4           4  499           -0.0  584   -2.000000                 0
#
#    Movement_Distance  Acceleration  Button     Angle           ID
# 0           2.236068   -164.440265      -1 -0.463648  001-tf2-315
# 1           1.414214     -0.821854      -1 -0.785398  001-tf2-315
# 2           1.000000     -0.414214      -1  0.000000  001-tf2-315
# 3           2.000000      1.000000      -1  0.000000  001-tf2-315
# 4           1.000000     -1.000000      -1  0.000000  001-tf2-315

# %%
# List of columns to select
selected_columns = ['Y', 'Stop_Duration', 'X', 'Jerk', 'Direction_Change', 'Movement_Distance', 'Acceleration', 'Button', 'Angle', 'ID']

# Select the desired columns
df_selected = data[selected_columns]
df_selected.head()
# Out:
#      Y  Stop_Duration    X        Jerk  Direction_Change  Movement_Distance  \
# 0  500           -0.0  579 -319.936258                 1           2.236068
# 1  499           -0.0  580  163.618411                 1           1.414214
# 2  499           -0.0  581    0.407641                 1           1.000000
# 3  499           -0.0  583    1.414214                 0           2.000000
# 4  499           -0.0  584   -2.000000                 0           1.000000
#
#    Acceleration  Button     Angle           ID
# 0   -164.440265      -1 -0.463648  001-tf2-315
# 1     -0.821854      -1 -0.785398  001-tf2-315
# 2     -0.414214      -1  0.000000  001-tf2-315
# 3      1.000000      -1  0.000000  001-tf2-315
# 4     -1.000000      -1  0.000000  001-tf2-315

# %%
df_selected.dropna()
# Out:
#           Y  Stop_Duration    X        Jerk  Direction_Change  \
# 0       500           -0.0  579 -319.936258                 1
# 1       499           -0.0  580  163.618411                 1
# 2       499           -0.0  581    0.407641                 1
# 3       499           -0.0  583    1.414214                 0
# 4       499           -0.0  584   -2.000000                 0
# ...     ...            ...  ...         ...               ...
# 653552  539           -0.0  961    0.000000                 1
# 653553  539           -0.0  960   -0.414214                 1
# 653554  540           -0.0  961    0.828427                 1
# 653555  540           -1.0  961   -1.828427                 1
# 653556  540           -1.0  961    1.414214                 0
#
#         Movement_Distance  Acceleration  Button     Angle           ID
# 0                2.236068   -164.440265      -1 -0.463648  001-tf2-315
# 1                1.414214     -0.821854      -1 -0.785398  001-tf2-315
# 2                1.000000     -0.414214      -1  0.000000  001-tf2-315
# 3                2.000000      1.000000      -1  0.000000  001-tf2-315
# 4                1.000000     -1.000000      -1  0.000000  001-tf2-315
# ...                   ...           ...     ...       ...          ...
# 653552           1.414214      0.000000      -1 -0.785398  021-tf2-403
# 653553           1.000000     -0.414214      -1  3.141593  021-tf2-403
# 653554           1.414214      0.414214      -1  0.785398  021-tf2-403
# 653555           0.000000     -1.414214      -1  0.000000  021-tf2-403
# 653556           0.000000      0.000000      -1  0.000000  021-tf2-403
#
# [653557 rows x 10 columns]

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

df = df_selected

# Use LabelEncoder to convert User_ID into numerical labels
encoder = LabelEncoder()
df['User_ID'] = encoder.fit_transform(df['ID'])

# Print the mapping for reference
mapping = dict(zip(encoder.classes_, range(len(encoder.classes_))))
print("Label mapping:", mapping)
# Out:
# Label mapping: {'001-tf2-315': 0, '002-tf2-315': 1, '004-tf2-315': 2, '007-tf2-317': 3, '008-tf2-317': 4, '009-tf2-320': 5, '010-tf2-320': 6, '013-tf2-326': 7, '014-tf2-328': 8, '015-tf2-328': 9, '016-tf2-328': 10, '017-tf2-328': 11, '018-tf2-330': 12, '019-tf2-403': 13, '020-tf2-403': 14, '021-tf2-403': 15}

# %%
df.drop(columns='ID', inplace=True)

# %%
df.head()
# Out:
#      Y  Stop_Duration    X        Jerk  Direction_Change  Movement_Distance  \
# 0  500           -0.0  579 -319.936258                 1           2.236068
# 1  499           -0.0  580  163.618411                 1           1.414214
# 2  499           -0.0  581    0.407641                 1           1.000000
# 3  499           -0.0  583    1.414214                 0           2.000000
# 4  499           -0.0  584   -2.000000                 0           1.000000
#
#    Acceleration  Button     Angle  User_ID
# 0   -164.440265      -1 -0.463648        0
# 1     -0.821854      -1 -0.785398        0
# 2     -0.414214      -1  0.000000        0
# 3      1.000000      -1  0.000000        0
# 4     -1.000000      -1  0.000000        0

# %% [markdown]
# # Relabel

# %%
# Relabel the User_ID column
df['User_ID'] = df['User_ID'].apply(lambda x: 0 if x == 0 else 1)

# Check the distribution of the relabeled User_ID
user_distribution = df['User_ID'].value_counts()

user_distribution
# Out:
# 1    624395
# 0     29162
# Name: User_ID, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# # normalize

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize the features
features = ['Y', 'Stop_Duration', 'X', 'Jerk', 'Direction_Change', 'Movement_Distance', 'Acceleration', 'Button', 'Angle']
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %% [markdown]
# # Sequencing

# %%
import numpy as np

# Create sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:(i+seq_length), :-1]
        y = data[i+seq_length][-1]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

X, y = create_sequences(df.values, 40)

# %% [markdown]
# # Normal Data Split

# %%
# Split the data for User_ID = 0
X_0 = X[y == 0]
y_0 = y[y == 0]
split_idx_0 = int(0.7 * len(X_0))
X_train_0, X_test_0 = X_0[:split_idx_0], X_0[split_idx_0:]
y_train_0, y_test_0 = y_0[:split_idx_0], y_0[split_idx_0:]

# Split the data for User_ID = 1
X_1 = X[y == 1]
y_1 = y[y == 1]
split_idx_1 = int(0.7 * len(X_1))
X_train_1, X_test_1 = X_1[:split_idx_1], X_1[split_idx_1:]
y_train_1, y_test_1 = y_1[:split_idx_1], y_1[split_idx_1:]

# Combine the training and test sets
X_train = np.concatenate([X_train_0, X_train_1])
y_train = np.concatenate([y_train_0, y_train_1])
X_test = np.concatenate([X_test_0, X_test_1])
y_test = np.concatenate([y_test_0, y_test_1])

# %% [markdown]
# # Model

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow as tf


precission = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
AUC_ROC = tf.keras.metrics.AUC(curve='ROC')

# 3. Build the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[precission, recall, AUC_ROC])

# %%
# 4. Train the model
model.fit(X_train, y_train, epochs=12, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/12
# 7148/7148 [==============================] - 560s 77ms/step - loss: 0.0691 - precision: 0.9830 - recall: 0.9864 - auc: 0.9707 - val_loss: 0.0318 - val_precision: 0.9898 - val_recall: 0.9999 - val_auc: 0.9896
# Epoch 2/12
# 7148/7148 [==============================] - 599s 84ms/step - loss: 0.0533 - precision: 0.9880 - recall: 0.9893 - auc: 0.9813 - val_loss: 0.0245 - val_precision: 0.9907 - val_recall: 0.9996 - val_auc: 0.9984
# Epoch 3/12
# 7148/7148 [==============================] - 595s 83ms/step - loss: 0.0464 - precision: 0.9895 - recall: 0.9902 - auc: 0.9886 - val_loss: 0.0316 - val_precision: 0.9888 - val_recall: 0.9991 - val_auc: 0.9978
# Epoch 4/12
# 7148/7148 [==============================] - 598s 84ms/step - loss: 0.0409 - precision: 0.9910 - recall: 0.9903 - auc: 0.9921 - val_loss: 0.0360 - val_precision: 0.9882 - val_recall: 0.9997 - val_auc: 0.9907
# Epoch 5/12
# 7148/7148 [==============================] - 590s 83ms/step - loss: 0.0368 - precision: 0.9923 - recall: 0.9909 - auc: 0.9939 - val_loss: 0.0342 - val_precision: 0.9891 - val_recall: 0.9994 - val_auc: 0.9850
# Epoch 6/12
# 7148/7148 [==============================] - 589s 82ms/step - loss: 0.0325 - precision: 0.9937 - recall: 0.9916 - auc: 0.9953 - val_loss: 0.0371 - val_precision: 0.9898 - val_recall: 0.9995 - val_auc: 0.9788
# Epoch 7/12
# 7148/7148 [==============================] - 606s 85ms/step - loss: 0.0282 - precision: 0.9947 - recall: 0.9927 - auc: 0.9964 - val_loss: 0.0427 - val_precision: 0.9890 - val_recall: 0.9998 - val_auc: 0.9712
# Epoch 8/12
# 7148/7148 [==============================] - 596s 83ms/step - loss: 0.0239 - precision: 0.9959 - recall: 0.9937 - auc: 0.9973 - val_loss: 0.0439 - val_precision: 0.9890 - val_recall: 0.9994 - val_auc: 0.9695
# Epoch 9/12
# 7148/7148 [==============================] - 602s 84ms/step - loss: 0.0199 - precision: 0.9964 - recall: 0.9950 - auc: 0.9981 - val_loss: 0.0624 - val_precision: 0.9860 - val_recall: 0.9994 - val_auc: 0.9507
# Epoch 10/12
# 7148/7148 [==============================] - 598s 84ms/step - loss: 0.0161 - precision: 0.9971 - recall: 0.9960 - auc: 0.9987 - val_loss: 0.0656 - val_precision: 0.9864 - val_recall: 0.9993 - val_auc: 0.9463
# Epoch 11/12
# 7148/7148 [==============================] - 597s 84ms/step - loss: 0.0138 - precision: 0.9976 - recall: 0.9967 - auc: 0.9988 - val_loss: 0.0665 - val_precision: 0.9858 - val_recall: 0.9997 - val_auc: 0.9475
# Epoch 12/12
# 7148/7148 [==============================] - 599s 84ms/step - loss: 0.0115 - precision: 0.9980 - recall: 0.9974 - auc: 0.9992 - val_loss: 0.0714 - val_precision: 0.9860 - val_recall: 0.9995 - val_auc: 0.9448

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 40, 50)            12000
#
#  dropout (Dropout)           (None, 40, 50)            0
#
#  lstm_1 (LSTM)               (None, 40, 50)            20200
#
#  dropout_1 (Dropout)         (None, 40, 50)            0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 52451 (204.89 KB)
# Trainable params: 52451 (204.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.save("LSTM_TF2.h5")
# Out:
# C:\Users\drago\anaconda3\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Eval

# %% [markdown]
# ## train

# %%
from sklearn.metrics import f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for the test set
y_pred_probs = model.predict(X_train)


# Convert probabilities to binary outputs
y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_probs]

# Calculate F1 score
f1 = f1_score(y_train, y_pred)
print(f"F1 Score: {f1}")
# Out:
# 14296/14296 [==============================] - 228s 16ms/step
# F1 Score: 0.9990947678497246

# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# Calculate and plot confusion matrix
cm = confusion_matrix(y_train, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# [[TN, FP],
# [FN, TP]]

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_train, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## test

# %%
# 5. Evaluate the model
loss, precision, recall, AUC = model.evaluate(X_test, y_test)
# Out:
# 6127/6127 [==============================] - 106s 17ms/step - loss: 0.0714 - precision: 0.9860 - recall: 0.9995 - auc: 0.9448

# %%
from sklearn.metrics import f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for the test set
y_pred_probs = model.predict(X_test)

# Convert probabilities to binary outputs
y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_probs]

# Calculate F1 score
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1}")
# Out:
# 6127/6127 [==============================] - 104s 17ms/step
# F1 Score: 0.9927148947000065

# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# Calculate and plot confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# [[TN, FP],
# [FN, TP]]

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
