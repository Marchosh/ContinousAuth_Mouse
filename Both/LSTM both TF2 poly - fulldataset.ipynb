# %%
import pandas as pd

data = pd.read_csv("alldata_featureselected.csv")
data.head()
# Out:
#    Unnamed: 0    Y  Stop_Duration    X        Jerk  Direction_Change  \
# 0           0  500           -0.0  579 -319.936258                 1
# 1           1  499           -0.0  580  163.618411                 1
# 2           2  499           -0.0  581    0.407641                 1
# 3           3  499           -0.0  583    1.414214                 0
# 4           4  499           -0.0  584   -2.000000                 0
#
#    Movement_Distance  Acceleration  Button     Angle           ID
# 0           2.236068   -164.440265      -1 -0.463648  001-tf2-315
# 1           1.414214     -0.821854      -1 -0.785398  001-tf2-315
# 2           1.000000     -0.414214      -1  0.000000  001-tf2-315
# 3           2.000000      1.000000      -1  0.000000  001-tf2-315
# 4           1.000000     -1.000000      -1  0.000000  001-tf2-315

# %%
# List of columns to select
selected_columns = ['Y', 'Stop_Duration', 'X', 'Jerk', 'Direction_Change', 'Movement_Distance', 'Acceleration', 'Button', 'Angle', 'ID']

# Select the desired columns
df_selected = data[selected_columns]
df_selected.head()
# Out:
#      Y  Stop_Duration    X        Jerk  Direction_Change  Movement_Distance  \
# 0  500           -0.0  579 -319.936258                 1           2.236068
# 1  499           -0.0  580  163.618411                 1           1.414214
# 2  499           -0.0  581    0.407641                 1           1.000000
# 3  499           -0.0  583    1.414214                 0           2.000000
# 4  499           -0.0  584   -2.000000                 0           1.000000
#
#    Acceleration  Button     Angle           ID
# 0   -164.440265      -1 -0.463648  001-tf2-315
# 1     -0.821854      -1 -0.785398  001-tf2-315
# 2     -0.414214      -1  0.000000  001-tf2-315
# 3      1.000000      -1  0.000000  001-tf2-315
# 4     -1.000000      -1  0.000000  001-tf2-315

# %%
df_selected.dropna(inplace=True)
df_selected
# Out:
# C:\Users\drago\AppData\Local\Temp\ipykernel_27900\3290963421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.dropna(inplace=True)
#            Y  Stop_Duration    X        Jerk  Direction_Change  \
# 0        500           -0.0  579 -319.936258                 1
# 1        499           -0.0  580  163.618411                 1
# 2        499           -0.0  581    0.407641                 1
# 3        499           -0.0  583    1.414214                 0
# 4        499           -0.0  584   -2.000000                 0
# ...      ...            ...  ...         ...               ...
# 1202664  539           -0.0  961    0.000000                 1
# 1202665  539           -0.0  960   -0.414214                 1
# 1202666  540           -0.0  961    0.828427                 1
# 1202667  540           -1.0  961   -1.828427                 1
# 1202668  540           -1.0  961    1.414214                 0
#
#          Movement_Distance  Acceleration  Button     Angle           ID
# 0                 2.236068   -164.440265      -1 -0.463648  001-tf2-315
# 1                 1.414214     -0.821854      -1 -0.785398  001-tf2-315
# 2                 1.000000     -0.414214      -1  0.000000  001-tf2-315
# 3                 2.000000      1.000000      -1  0.000000  001-tf2-315
# 4                 1.000000     -1.000000      -1  0.000000  001-tf2-315
# ...                    ...           ...     ...       ...          ...
# 1202664           1.414214      0.000000      -1 -0.785398  021-tf2-403
# 1202665           1.000000     -0.414214      -1  3.141593  021-tf2-403
# 1202666           1.414214      0.414214      -1  0.785398  021-tf2-403
# 1202667           0.000000     -1.414214      -1  0.000000  021-tf2-403
# 1202668           0.000000      0.000000      -1  0.000000  021-tf2-403
#
# [1202669 rows x 10 columns]

# %% [markdown]
# # label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

df = df_selected

# Use LabelEncoder to convert User_ID into numerical labels
encoder = LabelEncoder()
df['User_ID'] = encoder.fit_transform(df['ID'])

# Print the mapping for reference
mapping = dict(zip(encoder.classes_, range(len(encoder.classes_))))
print("Label mapping:", mapping)
# Out:
# Label mapping: {'001-tf2-315': 0, '002-tf2-315': 1, '004-poly-315': 2, '004-tf2-315': 3, '005-poly-315': 4, '007-poly-317': 5, '007-tf2-317': 6, '008-poly-317': 7, '008-tf2-317': 8, '009-poly-320': 9, '009-tf2-320': 10, '010-poly-317': 11, '010-tf2-320': 12, '011-poly-326': 13, '012-poly-326': 14, '013-poly-326': 15, '013-tf2-326': 16, '014-poly-328': 17, '014-tf2-328': 18, '015-poly-328': 19, '015-tf2-328': 20, '016-tf2-328': 21, '017-tf2-328': 22, '018-poly-330': 23, '018-tf2-330': 24, '019-poly-403': 25, '019-tf2-403': 26, '020-poly-403': 27, '020-tf2-403': 28, '021-tf2-403': 29}

# %%
df.drop(columns='ID', inplace=True)
df
# Out:
#            Y  Stop_Duration    X        Jerk  Direction_Change  \
# 0        500           -0.0  579 -319.936258                 1
# 1        499           -0.0  580  163.618411                 1
# 2        499           -0.0  581    0.407641                 1
# 3        499           -0.0  583    1.414214                 0
# 4        499           -0.0  584   -2.000000                 0
# ...      ...            ...  ...         ...               ...
# 1202664  539           -0.0  961    0.000000                 1
# 1202665  539           -0.0  960   -0.414214                 1
# 1202666  540           -0.0  961    0.828427                 1
# 1202667  540           -1.0  961   -1.828427                 1
# 1202668  540           -1.0  961    1.414214                 0
#
#          Movement_Distance  Acceleration  Button     Angle  User_ID
# 0                 2.236068   -164.440265      -1 -0.463648        0
# 1                 1.414214     -0.821854      -1 -0.785398        0
# 2                 1.000000     -0.414214      -1  0.000000        0
# 3                 2.000000      1.000000      -1  0.000000        0
# 4                 1.000000     -1.000000      -1  0.000000        0
# ...                    ...           ...     ...       ...      ...
# 1202664           1.414214      0.000000      -1 -0.785398       29
# 1202665           1.000000     -0.414214      -1  3.141593       29
# 1202666           1.414214      0.414214      -1  0.785398       29
# 1202667           0.000000     -1.414214      -1  0.000000       29
# 1202668           0.000000      0.000000      -1  0.000000       29
#
# [1202669 rows x 10 columns]

# %% [markdown]
# # relabel

# %%
# Relabel the User_ID column
df['User_ID'] = df['User_ID'].apply(lambda x: 0 if x == 0 else 1)

# Check the distribution of the relabeled User_ID
user_distribution = df['User_ID'].value_counts()

user_distribution
# Out:
# 1    1173507
# 0      29162
# Name: User_ID, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# # normalize

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize the features
features = ['Y', 'Stop_Duration', 'X', 'Jerk', 'Direction_Change', 'Movement_Distance', 'Acceleration', 'Button', 'Angle']
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %% [markdown]
# # Sequencing

# %%
import numpy as np

# Create sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:(i+seq_length), :-1]
        y = data[i+seq_length][-1]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

X, y = create_sequences(df.values, 40)

# %%
X.shape
# Out:
# (1202629, 40, 9)

# %% [markdown]
# # Splidata amnusaly

# %%
# Split the data for User_ID = 0
X_0 = X[y == 0]
y_0 = y[y == 0]
split_idx_0 = int(0.7 * len(X_0))
X_train_0, X_test_0 = X_0[:split_idx_0], X_0[split_idx_0:]
y_train_0, y_test_0 = y_0[:split_idx_0], y_0[split_idx_0:]

# Split the data for User_ID = 1

X_1 = X[y == 1]
y_1 = y[y == 1]
split_idx_1 = int(0.7 * len(X_1))
X_train_1, X_test_1 = X_1[:split_idx_1], X_1[split_idx_1:]
y_train_1, y_test_1 = y_1[:split_idx_1], y_1[split_idx_1:]

# Combine the training and test sets
X_train = np.concatenate([X_train_0, X_train_1])
y_train = np.concatenate([y_train_0, y_train_1])
X_test = np.concatenate([X_test_0, X_test_1])
y_test = np.concatenate([y_test_0, y_test_1])

# %% [markdown]
# # Model

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow as tf


precission = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
AUC_ROC = tf.keras.metrics.AUC(curve='ROC')

# 3. Build the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[precission, recall, AUC_ROC])

# %%
# 4. Train the model
model.fit(X_train, y_train, epochs=12, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/12
# 13154/13154 [==============================] - 471s 36ms/step - loss: 0.0490 - precision: 0.9885 - recall: 0.9932 - auc: 0.9658 - val_loss: 0.0158 - val_precision: 0.9954 - val_recall: 1.0000 - val_auc: 0.9947
# Epoch 2/12
# 13154/13154 [==============================] - 453s 34ms/step - loss: 0.0322 - precision: 0.9927 - recall: 0.9938 - auc: 0.9829 - val_loss: 0.0123 - val_precision: 0.9974 - val_recall: 0.9998 - val_auc: 0.9958
# Epoch 3/12
# 13154/13154 [==============================] - 439s 33ms/step - loss: 0.0296 - precision: 0.9931 - recall: 0.9943 - auc: 0.9883 - val_loss: 0.0183 - val_precision: 0.9935 - val_recall: 1.0000 - val_auc: 0.9951
# Epoch 4/12
# 13154/13154 [==============================] - 441s 34ms/step - loss: 0.0279 - precision: 0.9932 - recall: 0.9946 - auc: 0.9908 - val_loss: 0.0147 - val_precision: 0.9943 - val_recall: 1.0000 - val_auc: 0.9925
# Epoch 5/12
# 13154/13154 [==============================] - 435s 33ms/step - loss: 0.0255 - precision: 0.9939 - recall: 0.9951 - auc: 0.9924 - val_loss: 0.0123 - val_precision: 0.9962 - val_recall: 0.9998 - val_auc: 0.9918
# Epoch 6/12
# 13154/13154 [==============================] - 439s 33ms/step - loss: 0.0219 - precision: 0.9950 - recall: 0.9955 - auc: 0.9947 - val_loss: 0.0158 - val_precision: 0.9954 - val_recall: 1.0000 - val_auc: 0.9883
# Epoch 7/12
# 13154/13154 [==============================] - 436s 33ms/step - loss: 0.0193 - precision: 0.9957 - recall: 0.9960 - auc: 0.9961 - val_loss: 0.0198 - val_precision: 0.9936 - val_recall: 0.9998 - val_auc: 0.9841
# Epoch 8/12
# 13154/13154 [==============================] - 437s 33ms/step - loss: 0.0171 - precision: 0.9964 - recall: 0.9963 - auc: 0.9970 - val_loss: 0.0221 - val_precision: 0.9944 - val_recall: 0.9997 - val_auc: 0.9771
# Epoch 9/12
# 13154/13154 [==============================] - 437s 33ms/step - loss: 0.0143 - precision: 0.9970 - recall: 0.9969 - auc: 0.9980 - val_loss: 0.0252 - val_precision: 0.9938 - val_recall: 0.9994 - val_auc: 0.9751
# Epoch 10/12
# 13154/13154 [==============================] - 437s 33ms/step - loss: 0.0124 - precision: 0.9974 - recall: 0.9974 - auc: 0.9982 - val_loss: 0.0375 - val_precision: 0.9906 - val_recall: 0.9999 - val_auc: 0.9518
# Epoch 11/12
# 13154/13154 [==============================] - 426s 32ms/step - loss: 0.0103 - precision: 0.9979 - recall: 0.9977 - auc: 0.9987 - val_loss: 0.0274 - val_precision: 0.9928 - val_recall: 0.9999 - val_auc: 0.9683
# Epoch 12/12
# 13154/13154 [==============================] - 432s 33ms/step - loss: 0.0085 - precision: 0.9984 - recall: 0.9981 - auc: 0.9990 - val_loss: 0.0374 - val_precision: 0.9918 - val_recall: 0.9999 - val_auc: 0.9505

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 40, 50)            12000
#
#  dropout (Dropout)           (None, 40, 50)            0
#
#  lstm_1 (LSTM)               (None, 40, 50)            20200
#
#  dropout_1 (Dropout)         (None, 40, 50)            0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 52,451
# Trainable params: 52,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save("LSTM_BOTH.h5")

# %% [markdown]
# # Eval

# %% [markdown]
# ## Train

# %%
from sklearn.metrics import f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for the test set
y_pred_probs = model.predict(X_train)

# Convert probabilities to binary outputs
y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_probs]

# Calculate F1 score
f1 = f1_score(y_train, y_pred)
print(f"F1 Score: {f1}")
# Out:
# 26308/26308 [==============================] - 176s 7ms/step
# F1 Score: 0.9988790397472301

# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# Calculate and plot confusion matrix
cm = confusion_matrix(y_train, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# [[TN, FP],
# [FN, TP]]

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_train, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Test

# %%
loss, precision, recall, AUC = model.evaluate(X_test, y_test)
# Out:
# 11275/11275 [==============================] - 101s 9ms/step - loss: 0.0374 - precision: 0.9918 - recall: 0.9999 - auc: 0.9505

# %%
from sklearn.metrics import f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for the test set
y_pred_probs = model.predict(X_test)

# Convert probabilities to binary outputs
y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_probs]

# Calculate F1 score
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1}")
# Out:
# 11275/11275 [==============================] - 92s 8ms/step
# F1 Score: 0.9958243984134977

# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# Calculate and plot confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# [[TN, FP],
# [FN, TP]]

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
