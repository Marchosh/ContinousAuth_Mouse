# %%
import pandas as pd

data = pd.read_csv("alldata_featureselected.csv")
data.head()
# Out:
#    Unnamed: 0    Y  Stop_Duration    X        Jerk  Direction_Change  \
# 0           0  500           -0.0  579 -319.936258                 1
# 1           1  499           -0.0  580  163.618411                 1
# 2           2  499           -0.0  581    0.407641                 1
# 3           3  499           -0.0  583    1.414214                 0
# 4           4  499           -0.0  584   -2.000000                 0
#
#    Movement_Distance  Acceleration  Button     Angle           ID
# 0           2.236068   -164.440265      -1 -0.463648  001-tf2-315
# 1           1.414214     -0.821854      -1 -0.785398  001-tf2-315
# 2           1.000000     -0.414214      -1  0.000000  001-tf2-315
# 3           2.000000      1.000000      -1  0.000000  001-tf2-315
# 4           1.000000     -1.000000      -1  0.000000  001-tf2-315

# %%
# List of columns to select
selected_columns = ['Y', 'Stop_Duration', 'X', 'Jerk', 'Direction_Change', 'Movement_Distance', 'Acceleration', 'Button', 'Angle', 'ID']

# Select the desired columns
df_selected = data[selected_columns]
df_selected.head()
# Out:
#      Y  Stop_Duration    X        Jerk  Direction_Change  Movement_Distance  \
# 0  500           -0.0  579 -319.936258                 1           2.236068
# 1  499           -0.0  580  163.618411                 1           1.414214
# 2  499           -0.0  581    0.407641                 1           1.000000
# 3  499           -0.0  583    1.414214                 0           2.000000
# 4  499           -0.0  584   -2.000000                 0           1.000000
#
#    Acceleration  Button     Angle           ID
# 0   -164.440265      -1 -0.463648  001-tf2-315
# 1     -0.821854      -1 -0.785398  001-tf2-315
# 2     -0.414214      -1  0.000000  001-tf2-315
# 3      1.000000      -1  0.000000  001-tf2-315
# 4     -1.000000      -1  0.000000  001-tf2-315

# %%
df_selected.dropna(inplace=True)
df_selected
# Out:
# C:\Users\drago\AppData\Local\Temp\ipykernel_1580\3290963421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.dropna(inplace=True)
#            Y  Stop_Duration    X        Jerk  Direction_Change  \
# 0        500           -0.0  579 -319.936258                 1
# 1        499           -0.0  580  163.618411                 1
# 2        499           -0.0  581    0.407641                 1
# 3        499           -0.0  583    1.414214                 0
# 4        499           -0.0  584   -2.000000                 0
# ...      ...            ...  ...         ...               ...
# 1202664  539           -0.0  961    0.000000                 1
# 1202665  539           -0.0  960   -0.414214                 1
# 1202666  540           -0.0  961    0.828427                 1
# 1202667  540           -1.0  961   -1.828427                 1
# 1202668  540           -1.0  961    1.414214                 0
#
#          Movement_Distance  Acceleration  Button     Angle           ID
# 0                 2.236068   -164.440265      -1 -0.463648  001-tf2-315
# 1                 1.414214     -0.821854      -1 -0.785398  001-tf2-315
# 2                 1.000000     -0.414214      -1  0.000000  001-tf2-315
# 3                 2.000000      1.000000      -1  0.000000  001-tf2-315
# 4                 1.000000     -1.000000      -1  0.000000  001-tf2-315
# ...                    ...           ...     ...       ...          ...
# 1202664           1.414214      0.000000      -1 -0.785398  021-tf2-403
# 1202665           1.000000     -0.414214      -1  3.141593  021-tf2-403
# 1202666           1.414214      0.414214      -1  0.785398  021-tf2-403
# 1202667           0.000000     -1.414214      -1  0.000000  021-tf2-403
# 1202668           0.000000      0.000000      -1  0.000000  021-tf2-403
#
# [1202669 rows x 10 columns]

# %% [markdown]
# # label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

df = df_selected

# Use LabelEncoder to convert User_ID into numerical labels
encoder = LabelEncoder()
df['User_ID'] = encoder.fit_transform(df['ID'])

# Print the mapping for reference
mapping = dict(zip(encoder.classes_, range(len(encoder.classes_))))
print("Label mapping:", mapping)
# Out:
# Label mapping: {'001-tf2-315': 0, '002-tf2-315': 1, '004-poly-315': 2, '004-tf2-315': 3, '005-poly-315': 4, '007-poly-317': 5, '007-tf2-317': 6, '008-poly-317': 7, '008-tf2-317': 8, '009-poly-320': 9, '009-tf2-320': 10, '010-poly-317': 11, '010-tf2-320': 12, '011-poly-326': 13, '012-poly-326': 14, '013-poly-326': 15, '013-tf2-326': 16, '014-poly-328': 17, '014-tf2-328': 18, '015-poly-328': 19, '015-tf2-328': 20, '016-tf2-328': 21, '017-tf2-328': 22, '018-poly-330': 23, '018-tf2-330': 24, '019-poly-403': 25, '019-tf2-403': 26, '020-poly-403': 27, '020-tf2-403': 28, '021-tf2-403': 29}

# %%
df.drop(columns='ID', inplace=True)

# %%
df.head()
# Out:
#      Y  Stop_Duration    X        Jerk  Direction_Change  Movement_Distance  \
# 0  500           -0.0  579 -319.936258                 1           2.236068
# 1  499           -0.0  580  163.618411                 1           1.414214
# 2  499           -0.0  581    0.407641                 1           1.000000
# 3  499           -0.0  583    1.414214                 0           2.000000
# 4  499           -0.0  584   -2.000000                 0           1.000000
#
#    Acceleration  Button     Angle  User_ID
# 0   -164.440265      -1 -0.463648        0
# 1     -0.821854      -1 -0.785398        0
# 2     -0.414214      -1  0.000000        0
# 3      1.000000      -1  0.000000        0
# 4     -1.000000      -1  0.000000        0

# %% [markdown]
# # Relabel

# %%
# Relabel the User_ID column
df['User_ID'] = df['User_ID'].apply(lambda x: 0 if x == 0 else 1)

# Check the distribution of the relabeled User_ID
user_distribution = df['User_ID'].value_counts()

user_distribution
# Out:
# 1    1173507
# 0      29162
# Name: User_ID, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr()

# Plot the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# # Normalize

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize the features
features = ['Y', 'Stop_Duration', 'X', 'Jerk', 'Direction_Change', 'Movement_Distance', 'Acceleration', 'Button', 'Angle']
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %% [markdown]
# # Sequencing

# %%
import numpy as np

# Create sequences
def create_sequences(data, seq_length):
    xs, ys = [], []
    for i in range(len(data) - seq_length):
        x = data[i:(i+seq_length), :-1]
        y = data[i+seq_length][-1]
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

X, y = create_sequences(df.values, 40)

# %%
X.shape
# Out:
# (1202629, 40, 9)

# %% [markdown]
# # SplitData Manualy

# %%
# Split the data for User_ID = 0
X_0 = X[y == 0]
y_0 = y[y == 0]
split_idx_0 = int(0.7 * len(X_0))
X_train_0, X_test_0 = X_0[:split_idx_0], X_0[split_idx_0:]
y_train_0, y_test_0 = y_0[:split_idx_0], y_0[split_idx_0:]

# Split the data for User_ID = 1

X_1 = X[y == 1]
y_1 = y[y == 1]
split_idx_1 = int(0.7 * len(X_1))
X_train_1, X_test_1 = X_1[:split_idx_1], X_1[split_idx_1:]
y_train_1, y_test_1 = y_1[:split_idx_1], y_1[split_idx_1:]

# Combine the training and test sets
X_train = np.concatenate([X_train_0, X_train_1])
y_train = np.concatenate([y_train_0, y_train_1])
X_test = np.concatenate([X_test_0, X_test_1])
y_test = np.concatenate([y_test_0, y_test_1])

# %% [markdown]
# # Model

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
import tensorflow as tf

#Meetric
precission = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
AUC_ROC = tf.keras.metrics.AUC(curve='ROC')

# 3. Build the GRU model
model = Sequential()
model.add(GRU(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(50, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(50))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[precission, recall, AUC_ROC])

# %% [markdown]
# # Train

# %%
# 4. Train the model
model.fit(X_train, y_train, epochs=10, batch_size=256, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 3289/3289 [==============================] - 255s 77ms/step - loss: 0.0443 - precision: 0.9893 - recall: 0.9926 - auc: 0.9727 - val_loss: 0.0166 - val_precision: 0.9956 - val_recall: 0.9999 - val_auc: 0.9909
# Epoch 2/10
# 3289/3289 [==============================] - 262s 80ms/step - loss: 0.0330 - precision: 0.9928 - recall: 0.9935 - auc: 0.9801 - val_loss: 0.0273 - val_precision: 0.9852 - val_recall: 1.0000 - val_auc: 0.9921
# Epoch 3/10
# 3289/3289 [==============================] - 276s 84ms/step - loss: 0.0301 - precision: 0.9933 - recall: 0.9943 - auc: 0.9842 - val_loss: 0.0200 - val_precision: 0.9920 - val_recall: 1.0000 - val_auc: 0.9927
# Epoch 4/10
# 3289/3289 [==============================] - 275s 84ms/step - loss: 0.0261 - precision: 0.9938 - recall: 0.9953 - auc: 0.9908 - val_loss: 0.0254 - val_precision: 0.9896 - val_recall: 1.0000 - val_auc: 0.9884
# Epoch 5/10
# 3289/3289 [==============================] - 274s 83ms/step - loss: 0.0225 - precision: 0.9947 - recall: 0.9958 - auc: 0.9948 - val_loss: 0.0178 - val_precision: 0.9950 - val_recall: 0.9999 - val_auc: 0.9861
# Epoch 6/10
# 3289/3289 [==============================] - 262s 80ms/step - loss: 0.0188 - precision: 0.9956 - recall: 0.9962 - auc: 0.9969 - val_loss: 0.0220 - val_precision: 0.9928 - val_recall: 0.9999 - val_auc: 0.9822
# Epoch 7/10
# 3289/3289 [==============================] - 256s 78ms/step - loss: 0.0152 - precision: 0.9965 - recall: 0.9969 - auc: 0.9977 - val_loss: 0.0340 - val_precision: 0.9911 - val_recall: 0.9999 - val_auc: 0.9556
# Epoch 8/10
# 3289/3289 [==============================] - 259s 79ms/step - loss: 0.0120 - precision: 0.9974 - recall: 0.9976 - auc: 0.9985 - val_loss: 0.0318 - val_precision: 0.9915 - val_recall: 0.9998 - val_auc: 0.9618
# Epoch 9/10
# 3289/3289 [==============================] - 254s 77ms/step - loss: 0.0090 - precision: 0.9981 - recall: 0.9982 - auc: 0.9991 - val_loss: 0.0343 - val_precision: 0.9925 - val_recall: 1.0000 - val_auc: 0.9531
# Epoch 10/10
# 3289/3289 [==============================] - 255s 78ms/step - loss: 0.0069 - precision: 0.9985 - recall: 0.9986 - auc: 0.9994 - val_loss: 0.0277 - val_precision: 0.9943 - val_recall: 0.9999 - val_auc: 0.9620

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 40, 50)            9150
#
#  dropout (Dropout)           (None, 40, 50)            0
#
#  gru_1 (GRU)                 (None, 40, 50)            15300
#
#  dropout_1 (Dropout)         (None, 40, 50)            0
#
#  gru_2 (GRU)                 (None, 50)                15300
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 39,801
# Trainable params: 39,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save("GRU_BOTH.h5")

# %% [markdown]
# # Eval

# %% [markdown]
# ## Train

# %%
from sklearn.metrics import f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for the test set
y_pred_probs = model.predict(X_train)

# Convert probabilities to binary outputs
y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_probs]

# Calculate F1 score
f1 = f1_score(y_train, y_pred)
print(f"F1 Score: {f1}")
# Out:
# 26308/26308 [==============================] - 134s 5ms/step
# F1 Score: 0.9993435978873351

# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# Calculate and plot confusion matrix
cm = confusion_matrix(y_train, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# [[TN, FP],
# [FN, TP]]

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_train, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Test

# %%
loss, precision, recall, AUC = model.evaluate(X_test, y_test)
# Out:
# 11275/11275 [==============================] - 82s 7ms/step - loss: 0.0277 - precision: 0.9943 - recall: 0.9999 - auc: 0.9620

# %%
from sklearn.metrics import f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for the test set
y_pred_probs = model.predict(X_test)

# Convert probabilities to binary outputs
y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_probs]

# Calculate F1 score
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1}")
# Out:
# 11275/11275 [==============================] - 62s 5ms/step
# F1 Score: 0.9970668838296215

# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# Calculate and plot confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# [[TN, FP],
# [FN, TP]]

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Crossval

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
from sklearn.model_selection import StratifiedKFold

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %% [markdown]
# # Train Crss val

# %%
num_epochs = 7

for train_idx, val_idx in kfold.split(X, y):
    # Split data into train and validation sets
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    
    # Train the model with the current fold's data
    model.fit(X_train, y_train, epochs=num_epochs, batch_size=64, validation_data=(X_val, y_val), callbacks=[early_stopping])
    
    # Evaluate the model on the test set or perform any desired evaluation
    test_loss, recall, precission, auc = model.evaluate(X_test, y_test)
    print(test_loss, recall, precission, auc)

# %% [markdown]
# # Eval

# %%
from sklearn.metrics import f1_score, roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for the test set
y_pred_probs = model.predict(X_test)


# Convert probabilities to binary outputs
y_pred = [1 if prob > 0.5 else 0 for prob in y_pred_probs]

# Calculate F1 score
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1}")

# %%
from sklearn.metrics import f1_score, confusion_matrix, ConfusionMatrixDisplay

# Calculate and plot confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

# [[TN, FP],
# [FN, TP]]

# %%
# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
